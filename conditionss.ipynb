# %%
print("hello")
# Out:
# hello

# %% [markdown]
# # Check if a variable represents True

# %%
name=  ""
if name:  # continue in the if body if the variable represent True
    print("---the variable represents true")
else:
    print("--- the variable represents false ")
# Out:
# --- the variable represents false

# %%
# 2nd option
print(bool(name))
# Out:
# False

# %%
num1 = input("please enter num1 :")
print(type(num1))  # print type of variable
num2 = input("please enter num2: ")
print(type(num1))
res = num1 + num2
print(res)
# Out:
# <class 'str'>
# <class 'str'>
# 2524

# %%
# var1 + var2 ===> var1, var2  --are string ===> + operator concat

# %% [markdown]
# <h1> If condition </h1>

# %%
name= "Ahmed"
if name =='Ahmed':
    print("Hello Ahmed")
else:
    print("Nice to meet you")
# Out:
# Hello Ahmed

# %%
name= input("please enter name : ")
if name =='Ahmed':
    print("Hello Ahmed")
else:
    print("Nice to meet you")
# Out:
# Nice to meet you

# %%
# if user enters name = ahmed  --> print Hello Ahmed  --> else print nice to meet you, entered name
name= input("please enter name : ")
if name =='Ahmed':
    print("Hello Ahmed")
else:
    print("Nice to meet you", name )
# Out:
# Nice to meet you noha

# %%
num1 = input("please enter num1: ")
num1 = int(num1)

# %% [markdown]
# <h1 style='color:orange; text-align:center'>if condtion ==> check if number between 50 and 100 </h1>

# %%
num= 10
if num >=50 and num < 100:
    print('--- the given number between 50 and 100')
else:
    print("the given number out of range 50 and 100 ")
# Out:
# the given number out of range 50 and 100

# %%
numm = input("please enter number: ")
numm = int(numm)
if numm >=50 and numm < 100:
    print('--- the given number between 50 and 100--->', numm)
else:
    print("the given number out of range 50 and 100 ---> ", numm)
# Out:
# the given number out of range 50 and 100 --->  30

# %%
numm = input("please enter number: ")
numm = int(numm)
if 50 <= numm < 100:
    print('--- the given number between 50 and 100--->', numm)
else:
    print("the given number out of range 50 and 100 ---> ", numm)

# %% [markdown]
# <h1 style='color:red'>Input</h1>

# %%
# password = input("please enter password ")

anyvalue = input("")
print(anyvalue)
# Out:
# sd

# %% [markdown]
# # days Eaxample

# %%
day = input("please enter day: ")
if day=="Sunday":
    print("wish you a good week")
if day == 'Tuesday':
    print('The weekend is near')
if day== 'Friday':
    print('Enjoy your weekend')

if (day=='Saturday' or day=='Wednesday' or day=='Thursday'
        or day== 'Monday' and( day != 'Sunday' or day !='Tuesday' or day !='Friday') ):
    print("Ma3lsh")
else:
    print("-- please enter the day again ")
# Out:
# wish you a good week
# -- please enter the day again

# %%
# 3 numbers
num1 = 100
num2 = 50
num3 = 40

if num1 < num2 and num1 < num3:
    print("=== num1 is the smallest", num1)

if num2 < num1 and num2 < num3:
    print("=== num2 is  the smallest", num2)

if num3 < num1 and num3 < num2:
    print('=== num3 is the smallest', num3)
# Out:
# === num3 is the smallest 40

# %% [markdown]
# # input from user

# %%
num1 = input("please enter num1: ")
num1 = int(num1)
num2 = input("please enter num2: ")
num2 = int(num2)
num3 = input("please enter num3: ")
num3 = int(num3)

if num1 < num2 and num1 < num3:
    print("=== num1 is the smallest", num1)

if num2 < num1 and num2 < num3:
    print("=== num2 is  the smallest", num2)

if num3 < num1 and num3 < num2:
    print('=== num3 is the smallest', num3)
# Out:
# === num2 is  the smallest 35

# %% [markdown]
# # using elif

# %%
num1 = input("please enter num1: ")
num1 = int(num1)
num2 = input("please enter num2: ")
num2 = int(num2)
num3 = input("please enter num3: ")
num3 = int(num3)

if num1 < num2 and num1 < num3:
    print("=== num1 is the smallest", num1)
elif num2 < num1 and num2 < num3:
    print("=== num2 is  the smallest", num2)
elif num3 < num1 and num3 < num2:
    print('=== num3 is the smallest', num3)
