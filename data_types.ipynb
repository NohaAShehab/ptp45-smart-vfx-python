# %%
print("type conversion")
# Out:
# type conversion

# %% [markdown]
# # convert string to integer

# %%
year = "2025"
print(year, type(year))
print("--- after converting ........")
year = int(year)
print(year, type(year))
# Out:
# 2025 <class 'str'>
# --- after converting ........
# 2025 <class 'int'>

# %% [markdown]
# # check this

# %%
name = 'noha'
print(name, type(name))

print("--------- after converting")
name = int(name)
print(name, type(name))
# Out:
# noha <class 'str'>
# --------- after converting
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 5
#       2 print(name, type(name))
#       4 print("--------- after converting")
# ----> 5 name = int(name)
#       6 print(name, type(name))
#
# ValueError: invalid literal for int() with base 10: 'noha'

# %% [markdown]
# <h1 style='color:green; text-align:center'> Example</h1>

# %%
message = input("Please enter any value : ") # input function always save input data into string
print(message, type(message))
# Out:
# 100 <class 'str'>

# %% [markdown]
# <h1 style='color:blue; text-align:center'> Calculator</h1>

# %%
num1 = input("please enter num1  ")
num1 = int(num1)

num2 = input("please enter num2  ")
num2 = int(num2)

res = num1 + num2
print(res)
# Out:
# 77
