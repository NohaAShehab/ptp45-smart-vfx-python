# %% [markdown]
# # String operation

# %%
from dis import pretty_flags

car = "Porcshe"  # string

print(car)  ### () --> calling function
# Out:
# Porcshe

# %%
# get len of this string
print(len(car))
# Out:
# 7

# %%
print(car.count("r"))
# Out:
# 1

# %%
message = 'Hello'
print(message.count("l"))
# Out:
# 2

# %%
print(message.count("L"))
# Out:
# 0

# %%
# noha
# n
# o
# h
# a

#
name = 'ahmed'
print(name[0])
# Out:
# a

# %%
print(name[6])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(name[6])
#
# IndexError: string index out of range

# %%
name = "ahmed"
index = 0
while index  < len(name):
    print(  name[index]    )
    index +=1 # index = index + 1
# Out:
# a
# a
# a
# a

# %%
course = "python"

#
print(course[2])
# Out:
# t

# %%
iti = "information technology institute"
print(iti.count("i"))
# Out:
# 4

# %%
index = 0
i_occurence = 0
while index < len(iti):  # while index < length of the word
    if iti[index]=="i": # check char at index === i ??
        i_occurence +=1  # if yes increment occurence by 1
    index +=1 # to go to the next char

print(i_occurence)
# Out:
# 4

# %% [markdown]
# # write a program to conver first char of each word to be Capital letter

# %%
# mjyuyuiyiy name is noha.

# char in lowercase ==> need to convert it to uppercase
c = "noha"
print(c.upper()) # return new string contains all chars in upper case
# Out:
# NOHA

# %%
iti = "information technology institute"
upperiti = iti.upper()  # return new string --> all chars in ==> are upper cases???

print(upperiti)
# Out:
# INFORMATION TECHNOLOGY INSTITUTE

# %%
iti = "information technology institute" ## ??
index = 0
newstring = ""

while index < len(iti):
    char = iti[index]
    if index==0:
        char = char.upper()
        newstring +=char
    else:
        previousChar = iti[index-1]
        if previousChar == " ":
            char = char.upper()
            newstring +=char
        else:
            newstring +=char
    index
print(newstring)
# Out:
# Information Technology Institute

# %%
###########
# given string noha ====> ahon

anystring = "python"
index = len(anystring)-1
newstring = ""
while index > -1 :
    char = anystring[index]
    newstring +=char
    index -=1

print(newstring)
# Out:
# nohtyp

# %% [markdown]
# # you need convert any char to lower case

# %%
grade = 'A'  # capital or small ===> capital letter
print(grade.lower())

# noha ===> NoHa

# %%
word = input("please enter any word: ")
newword = ""
index = 0

while index < len(word):
    char = word[index]
    # char capital --> index %2 ==0
    if index %2==0:
        newword += char.upper()
    else:
        newword += char.lower()
    index +=1

print("origin= "+ word)
print("newword= "+ newword)
# Out:
# origin= python
# newword= PyThOn
