# %% [markdown]
# <h1> Operations </h1>

# %%
num1= 200
num2 = 10
summ = num1  + num2
print(summ)
diff = num1 - num2
print(diff)
mull = num1 * num2
print(mull)
div = num1 / num2
print(div)
# Out:
# 210
# 190
# 2000
# 20.0

# %% [markdown]
# <h1> Assignement Operator </h1>

# %%
name = 'ahmed'

grade = 10

# %%
grade = grade + 5   # reassing
print(grade)
# Out:
# 15

# %%
grade +=10   # grade = grade + 10
print(grade)
# Out:
# 25

# %%
num = 20
num = num + 50   # 70
print(num)
# Out:
# 70

# %%
num2 = 100
num2 +=20     # num2 = num2+20
print(num2)
# Out:
# 120

# %%
print(num)
num +=100
print(num)
# Out:
# 70
# 170

# %% [markdown]
# <h1 style='color:orange'> Comparison </h1>

# %%
grade = 100

std_grade = 50

print(grade== std_grade)
# Out:
# False

# %%
print(grade > std_grade)
# Out:
# True

# %%
name= '20'
age = 20
print(name== age)     # == compares type and value
# Out:
# False

# %%
print(name > age)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 print(name > age)
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %% [markdown]
# <h1> Assume <span style='color:green'> True=1 </span> ,  <span style='color:red'> False=0 </span> </h1>

# %%
print(1== True )
# Out:
# True

# %%
print( 100 == True )  # false
# Out:
# False

# %%
print(0 == False )
# Out:
# True

# %% [markdown]
# <h1> Logical Operators </h1>

# %% [markdown]
# # And

# %%
name= 'Ahmed'
grade =80

if name=='Ahmed' and grade >=85:
    print("Congratulations Ahmed You have passed")
else:
    print("---- Sorry you didn't pass ")
# Out:
# ---- Sorry you didn't pass

# %%
print(name=='Ahmed' and grade >=85)
# Out:
# False

# %%
grade = 100
print(name=='Ahmed' and grade >=85)
# Out:
# True

# %% [markdown]
# # check this senario

# %%
num = 10
if num> 5 and num %2==0:
    print("the number is greater than 5 and even number ")
else:
    print("--- number may be less than 5 or odd number")
# Out:
# the number is greater than 5 and even number

# %%
name="Mohamed"
std = "Ali"
print(name == std)  # == compare the values

# %% [markdown]
# <h1> TIP </h1>

# %%
name = "Ahmed"
if name:
    print("Hiiii")
else:
    print("byyeee")
# Out:
# Hiiii

# %%
name = False
if name:
    print("Hiiii")
else:
    print("byyeee")
# Out:
# byyeee

# %%
name = ""   # this not equal false ==> represent False
if name:
    print("Hiiii")
else:
    print("byyeee")
# Out:
# byyeee

# %%
val = 0
if val==0:
    print("--- value is zero")
# Out:
# --- value is zero

# %%
if val:
    print("--- value found")
else:
    print("---- not val ")
# Out:
# ---- not val

# %%
print(""==False)
# Out:
# False

# %%
# I need to check if value represnet True or False

value= 20
if value:
    print("True")
else:
    print(False)
# Out:
# True

# %%
print(value)
# Out:
# 20

# %% [markdown]
# #

# %% [markdown]
# # cast value to bool

# %%
print(bool(20))
# Out:
# True

# %%
print(bool(''))
# Out:
# False

# %%
print(bool(" "))  # this string is not empty -- it contains space
# Out:
# True

# %%
# check this

print("Ahmed" and 10 and "iti" and True and 1000)
# Out:
# 1000

# %%
print("Mariam")
# Out:
# Mariam

# %%
print("Ahmed" and 10 and "iti" and None and 1000)
# Out:
# None

# %%
print("Ahmed" and 10 and "iti" and False and 1000 )
# Out:
# False
